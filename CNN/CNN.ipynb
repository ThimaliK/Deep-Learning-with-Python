# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

import pickle

import numpy as np

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

model = Sequential()

model.add(Conv2D(256, (3, 3), input_shape=X.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

model.add(Dense(64))
model.add(Activation('relu'))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

X = np.array(X)
y = np.array(y)

model.fit(X, y, batch_size=32, epochs=3, validation_split=0.3)
# Out:
# Epoch 1/3
# 546/546 [==============================] - 336s 615ms/step - loss: 0.6459 - accuracy: 0.6216 - val_loss: 0.6335 - val_accuracy: 0.6539
# Epoch 2/3
# 546/546 [==============================] - 312s 571ms/step - loss: 0.5495 - accuracy: 0.7286 - val_loss: 0.5168 - val_accuracy: 0.7425
# Epoch 3/3
# 546/546 [==============================] - 305s 559ms/step - loss: 0.4931 - accuracy: 0.7625 - val_loss: 0.5176 - val_accuracy: 0.7374

# %%
model.save('CNN1.model')
# Out:
# INFO:tensorflow:Assets written to: CNN1.model\assets

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

from tensorflow.keras.callbacks import TensorBoard

import pickle

import numpy as np

import time

NAME = "cats-vs-dogs-cnn-64by2-{}".format(int(time.time()))
tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))

# gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction = 0.333)
# sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

model = Sequential()

model.add(Conv2D(256, (3, 3), input_shape=X.shape[1:]))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(256, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors

# model.add(Dense(64))
# model.add(Activation('relu'))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

X = np.array(X)
y = np.array(y)

model.fit(X, y, 
          batch_size=32, 
          epochs=20, 
          validation_split=0.3, 
          callbacks=[tensorboard])
# Out:
# Epoch 1/20
# 546/546 [==============================] - 360s 658ms/step - loss: 0.6402 - accuracy: 0.6241 - val_loss: 0.5746 - val_accuracy: 0.7028
# Epoch 2/20
# 546/546 [==============================] - 367s 672ms/step - loss: 0.5646 - accuracy: 0.7129 - val_loss: 0.5507 - val_accuracy: 0.7209
# Epoch 3/20
# 546/546 [==============================] - 409s 748ms/step - loss: 0.5188 - accuracy: 0.7491 - val_loss: 0.5220 - val_accuracy: 0.7444
# Epoch 4/20
# 546/546 [==============================] - 413s 756ms/step - loss: 0.4815 - accuracy: 0.7740 - val_loss: 0.5272 - val_accuracy: 0.7390
# Epoch 5/20
# 546/546 [==============================] - 400s 732ms/step - loss: 0.4605 - accuracy: 0.7831 - val_loss: 0.4733 - val_accuracy: 0.7746
# Epoch 6/20
# 546/546 [==============================] - 399s 731ms/step - loss: 0.4411 - accuracy: 0.7989 - val_loss: 0.5130 - val_accuracy: 0.7468
# Epoch 7/20
# 546/546 [==============================] - 382s 700ms/step - loss: 0.4281 - accuracy: 0.8046 - val_loss: 0.4606 - val_accuracy: 0.7837
# Epoch 8/20
# 546/546 [==============================] - 381s 697ms/step - loss: 0.4065 - accuracy: 0.8151 - val_loss: 0.4569 - val_accuracy: 0.7914
# Epoch 9/20
# 546/546 [==============================] - 383s 701ms/step - loss: 0.3895 - accuracy: 0.8271 - val_loss: 0.4722 - val_accuracy: 0.7839
# Epoch 10/20
# 546/546 [==============================] - 390s 715ms/step - loss: 0.3744 - accuracy: 0.8336 - val_loss: 0.4636 - val_accuracy: 0.7853
# Epoch 11/20
# 546/546 [==============================] - 381s 699ms/step - loss: 0.3579 - accuracy: 0.8438 - val_loss: 0.4504 - val_accuracy: 0.7937
# Epoch 12/20
# 546/546 [==============================] - 341s 625ms/step - loss: 0.3425 - accuracy: 0.8500 - val_loss: 0.4436 - val_accuracy: 0.7992
# Epoch 13/20
# 546/546 [==============================] - 313s 573ms/step - loss: 0.3265 - accuracy: 0.8593 - val_loss: 0.4521 - val_accuracy: 0.7982
# Epoch 14/20
# 546/546 [==============================] - 308s 564ms/step - loss: 0.3109 - accuracy: 0.8671 - val_loss: 0.4466 - val_accuracy: 0.7994
# Epoch 15/20
# 546/546 [==============================] - 308s 564ms/step - loss: 0.3006 - accuracy: 0.8714 - val_loss: 0.4667 - val_accuracy: 0.7952
# Epoch 16/20
# 546/546 [==============================] - 308s 565ms/step - loss: 0.2843 - accuracy: 0.8792 - val_loss: 0.4871 - val_accuracy: 0.7870
# Epoch 17/20
# 546/546 [==============================] - 341s 625ms/step - loss: 0.2788 - accuracy: 0.8829 - val_loss: 0.4759 - val_accuracy: 0.7946
# Epoch 18/20
# 546/546 [==============================] - 361s 661ms/step - loss: 0.2618 - accuracy: 0.8926 - val_loss: 0.4963 - val_accuracy: 0.7926
# Epoch 19/20
# 546/546 [==============================] - 360s 660ms/step - loss: 0.2547 - accuracy: 0.8925 - val_loss: 0.5717 - val_accuracy: 0.7712
# Epoch 20/20
# 546/546 [==============================] - 360s 660ms/step - loss: 0.2439 - accuracy: 0.9002 - val_loss: 0.5141 - val_accuracy: 0.7944

# %%
import time

import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

from tensorflow.keras.callbacks import TensorBoard

import pickle

import numpy as np

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

dense_layers = [0, 1, 2]

layer_sizes = [32, 64, 128]

conv_layers = [1, 2, 3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))
            print(NAME)
            
            model = Sequential()

            model.add(Conv2D(layer_size, (3, 3), input_shape=X.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))
            
            for l in range(conv_layer - 1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))
                
            model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
            
            for l in range(dense_layer):
                model.add(Dense(layer_size))
                model.add(Activation('relu'))
            

            # model.add(Dense(64))
            # model.add(Activation('relu'))

            model.add(Dense(1))
            model.add(Activation('sigmoid'))

            model.compile(loss='binary_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'])

            X = np.array(X)
            y = np.array(y)

            model.fit(X, y, 
                      batch_size=32, 
                      epochs=20, 
                      validation_split=0.3, 
                      callbacks=[tensorboard])
# Out:
# 1-conv-32-nodes-0-dense-1622043683
# Epoch 1/20
# 546/546 [==============================] - 16s 28ms/step - loss: 0.6298 - accuracy: 0.6493 - val_loss: 0.5891 - val_accuracy: 0.6982
# Epoch 2/20
# 546/546 [==============================] - 14s 26ms/step - loss: 0.5583 - accuracy: 0.7198 - val_loss: 0.5723 - val_accuracy: 0.6963
# Epoch 3/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.5251 - accuracy: 0.7449 - val_loss: 0.5503 - val_accuracy: 0.7273
# Epoch 4/20
# 546/546 [==============================] - 15s 27ms/step - loss: 0.5024 - accuracy: 0.7585 - val_loss: 0.5380 - val_accuracy: 0.7364
# Epoch 5/20
# 546/546 [==============================] - 16s 29ms/step - loss: 0.4846 - accuracy: 0.7713 - val_loss: 0.5344 - val_accuracy: 0.7360
# Epoch 6/20
# 546/546 [==============================] - 15s 27ms/step - loss: 0.4705 - accuracy: 0.7793 - val_loss: 0.5252 - val_accuracy: 0.7475
# Epoch 7/20
# 546/546 [==============================] - 15s 27ms/step - loss: 0.4596 - accuracy: 0.7867 - val_loss: 0.5309 - val_accuracy: 0.7451
# Epoch 8/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.4452 - accuracy: 0.7926 - val_loss: 0.5279 - val_accuracy: 0.7468
# Epoch 9/20
# 546/546 [==============================] - 14s 25ms/step - loss: 0.4365 - accuracy: 0.7996 - val_loss: 0.5443 - val_accuracy: 0.7384
# Epoch 10/20
# 546/546 [==============================] - 15s 27ms/step - loss: 0.4287 - accuracy: 0.8028 - val_loss: 0.5417 - val_accuracy: 0.7408
# Epoch 11/20
# 546/546 [==============================] - 15s 28ms/step - loss: 0.4175 - accuracy: 0.8120 - val_loss: 0.5367 - val_accuracy: 0.7461
# Epoch 12/20
# 546/546 [==============================] - 17s 32ms/step - loss: 0.4092 - accuracy: 0.8127 - val_loss: 0.5443 - val_accuracy: 0.7418
# Epoch 13/20
# 546/546 [==============================] - 18s 33ms/step - loss: 0.4034 - accuracy: 0.8202 - val_loss: 0.5413 - val_accuracy: 0.7443
# Epoch 14/20
# 546/546 [==============================] - 15s 28ms/step - loss: 0.3911 - accuracy: 0.8256 - val_loss: 0.5538 - val_accuracy: 0.7372
# Epoch 15/20
# 546/546 [==============================] - 16s 29ms/step - loss: 0.3832 - accuracy: 0.8310 - val_loss: 0.5491 - val_accuracy: 0.7402
# Epoch 16/20
# 546/546 [==============================] - 15s 27ms/step - loss: 0.3778 - accuracy: 0.8334 - val_loss: 0.5679 - val_accuracy: 0.7333
# Epoch 17/20
# 546/546 [==============================] - 15s 27ms/step - loss: 0.3684 - accuracy: 0.8376 - val_loss: 0.5717 - val_accuracy: 0.7338
# Epoch 18/20
# 546/546 [==============================] - 14s 26ms/step - loss: 0.3620 - accuracy: 0.8431 - val_loss: 0.5617 - val_accuracy: 0.7392
# Epoch 19/20
# 546/546 [==============================] - 15s 27ms/step - loss: 0.3517 - accuracy: 0.8465 - val_loss: 0.5646 - val_accuracy: 0.7369
# Epoch 18/20
# 546/546 [==============================] - 29s 53ms/step - loss: 0.2736 - accuracy: 0.8835 - val_loss: 0.4416 - val_accuracy: 0.8075
# Epoch 19/20
# 546/546 [==============================] - 29s 52ms/step - loss: 0.2596 - accuracy: 0.8920 - val_loss: 0.4602 - val_accuracy: 0.8045
# Epoch 20/20
# 546/546 [==============================] - 29s 52ms/step - loss: 0.2522 - accuracy: 0.8943 - val_loss: 0.4571 - val_accuracy: 0.8076
# 1-conv-64-nodes-0-dense-1622045123
# Epoch 1/20
# 546/546 [==============================] - 28s 52ms/step - loss: 0.6282 - accuracy: 0.6482 - val_loss: 0.5887 - val_accuracy: 0.6943
# Epoch 2/20
# 546/546 [==============================] - 27s 49ms/step - loss: 0.5485 - accuracy: 0.7268 - val_loss: 0.5540 - val_accuracy: 0.7198
# Epoch 3/20
# 546/546 [==============================] - 27s 49ms/step - loss: 0.5102 - accuracy: 0.7570 - val_loss: 0.5841 - val_accuracy: 0.7018
# Epoch 4/20
# 546/546 [==============================] - 26s 49ms/step - loss: 0.4870 - accuracy: 0.7681 - val_loss: 0.5427 - val_accuracy: 0.7298
# Epoch 5/20
# 546/546 [==============================] - 26s 48ms/step - loss: 0.4686 - accuracy: 0.7836 - val_loss: 0.5279 - val_accuracy: 0.7386
# Epoch 6/20
# 546/546 [==============================] - 27s 49ms/step - loss: 0.4482 - accuracy: 0.7925 - val_loss: 0.5363 - val_accuracy: 0.7394
# Epoch 7/20
# 546/546 [==============================] - 27s 49ms/step - loss: 0.4376 - accuracy: 0.7994 - val_loss: 0.5365 - val_accuracy: 0.7385
# Epoch 8/20
# 546/546 [==============================] - 26s 48ms/step - loss: 0.4186 - accuracy: 0.8124 - val_loss: 0.5599 - val_accuracy: 0.7255
# Epoch 9/20
# 546/546 [==============================] - 26s 47ms/step - loss: 0.4035 - accuracy: 0.8192 - val_loss: 0.5541 - val_accuracy: 0.7324
# Epoch 10/20
# 546/546 [==============================] - 25s 46ms/step - loss: 0.3882 - accuracy: 0.8317 - val_loss: 0.5465 - val_accuracy: 0.7445
# Epoch 11/20
# 546/546 [==============================] - 25s 45ms/step - loss: 0.3731 - accuracy: 0.8363 - val_loss: 0.5429 - val_accuracy: 0.7440
# Epoch 12/20
# 546/546 [==============================] - 25s 45ms/step - loss: 0.3593 - accuracy: 0.8454 - val_loss: 0.5570 - val_accuracy: 0.7372
# Epoch 13/20
# 546/546 [==============================] - 24s 44ms/step - loss: 0.3477 - accuracy: 0.8527 - val_loss: 0.5628 - val_accuracy: 0.7392
# Epoch 14/20
# 546/546 [==============================] - 25s 45ms/step - loss: 0.3352 - accuracy: 0.8586 - val_loss: 0.5729 - val_accuracy: 0.7380
# Epoch 15/20
# 546/546 [==============================] - 25s 45ms/step - loss: 0.3197 - accuracy: 0.8667 - val_loss: 0.6044 - val_accuracy: 0.7214
# Epoch 16/20
# 546/546 [==============================] - 25s 45ms/step - loss: 0.3072 - accuracy: 0.8716 - val_loss: 0.5765 - val_accuracy: 0.7397
# Epoch 17/20
# 546/546 [==============================] - 27s 49ms/step - loss: 0.2959 - accuracy: 0.8791 - val_loss: 0.5918 - val_accuracy: 0.7348
# Epoch 18/20
# 546/546 [==============================] - 26s 48ms/step - loss: 0.2818 - accuracy: 0.8885 - val_loss: 0.6257 - val_accuracy: 0.7326
# Epoch 19/20
# 546/546 [==============================] - 26s 48ms/step - loss: 0.2728 - accuracy: 0.8921 - val_loss: 0.6142 - val_accuracy: 0.7280
# Epoch 20/20
# 546/546 [==============================] - 27s 49ms/step - loss: 0.2627 - accuracy: 0.8966 - val_loss: 0.6151 - val_accuracy: 0.7316
# 2-conv-64-nodes-0-dense-1622045642
# Epoch 1/20
# 546/546 [==============================] - 57s 104ms/step - loss: 0.6432 - accuracy: 0.6260 - val_loss: 0.5838 - val_accuracy: 0.6856
# Epoch 2/20
# 546/546 [==============================] - 56s 102ms/step - loss: 0.5424 - accuracy: 0.7296 - val_loss: 0.5152 - val_accuracy: 0.7493
# Epoch 3/20
# 546/546 [==============================] - 53s 97ms/step - loss: 0.5000 - accuracy: 0.7563 - val_loss: 0.4989 - val_accuracy: 0.7561
# Epoch 4/20
# 546/546 [==============================] - 53s 96ms/step - loss: 0.4722 - accuracy: 0.7757 - val_loss: 0.4914 - val_accuracy: 0.7586
# Epoch 5/20
# 546/546 [==============================] - 54s 98ms/step - loss: 0.4499 - accuracy: 0.7922 - val_loss: 0.4919 - val_accuracy: 0.7644
# Epoch 6/20
# 546/546 [==============================] - 54s 99ms/step - loss: 0.4316 - accuracy: 0.8027 - val_loss: 0.4630 - val_accuracy: 0.7747
# Epoch 7/20
# 546/546 [==============================] - 55s 100ms/step - loss: 0.4093 - accuracy: 0.8138 - val_loss: 0.4563 - val_accuracy: 0.7865
# Epoch 8/20
# 546/546 [==============================] - 52s 95ms/step - loss: 0.3935 - accuracy: 0.8228 - val_loss: 0.4589 - val_accuracy: 0.7865
# Epoch 9/20
# 546/546 [==============================] - 51s 94ms/step - loss: 0.3720 - accuracy: 0.8343 - val_loss: 0.4575 - val_accuracy: 0.7831
# Epoch 10/20
# 546/546 [==============================] - 52s 94ms/step - loss: 0.3591 - accuracy: 0.8402 - val_loss: 0.4740 - val_accuracy: 0.7827
# Epoch 11/20
# 546/546 [==============================] - 53s 98ms/step - loss: 0.3409 - accuracy: 0.8495 - val_loss: 0.4841 - val_accuracy: 0.7774
# Epoch 12/20
# 546/546 [==============================] - 61s 111ms/step - loss: 0.3261 - accuracy: 0.8565 - val_loss: 0.4563 - val_accuracy: 0.7883
# Epoch 13/20
# 546/546 [==============================] - 56s 103ms/step - loss: 0.3125 - accuracy: 0.8660 - val_loss: 0.4930 - val_accuracy: 0.7745
# Epoch 14/20
# 546/546 [==============================] - 57s 104ms/step - loss: 0.3009 - accuracy: 0.8702 - val_loss: 0.4557 - val_accuracy: 0.7922
# Epoch 15/20
# 546/546 [==============================] - 59s 108ms/step - loss: 0.2786 - accuracy: 0.8809 - val_loss: 0.4663 - val_accuracy: 0.7942
# Epoch 16/20
# 546/546 [==============================] - 66s 121ms/step - loss: 0.2599 - accuracy: 0.8969 - val_loss: 0.6220 - val_accuracy: 0.7348
# Epoch 15/20
# 546/546 [==============================] - 67s 123ms/step - loss: 0.2427 - accuracy: 0.9067 - val_loss: 0.6714 - val_accuracy: 0.7270
# Epoch 16/20
# 546/546 [==============================] - 67s 122ms/step - loss: 0.2277 - accuracy: 0.9150 - val_loss: 0.6588 - val_accuracy: 0.7324
# Epoch 17/20
# 546/546 [==============================] - 65s 119ms/step - loss: 0.2165 - accuracy: 0.9196 - val_loss: 0.6766 - val_accuracy: 0.7286
# Epoch 18/20
# 546/546 [==============================] - 65s 119ms/step - loss: 0.1934 - accuracy: 0.9316 - val_loss: 0.6829 - val_accuracy: 0.7289
# Epoch 19/20
# 546/546 [==============================] - 67s 122ms/step - loss: 0.1830 - accuracy: 0.9398 - val_loss: 0.7027 - val_accuracy: 0.7314
# Epoch 20/20
# 546/546 [==============================] - 67s 124ms/step - loss: 0.1691 - accuracy: 0.9431 - val_loss: 0.7129 - val_accuracy: 0.7285
# 2-conv-128-nodes-0-dense-1622049368
# Epoch 1/20
# 546/546 [==============================] - 152s 277ms/step - loss: 0.6262 - accuracy: 0.6480 - val_loss: 0.5895 - val_accuracy: 0.6813
# Epoch 2/20
# 546/546 [==============================] - 142s 261ms/step - loss: 0.5274 - accuracy: 0.7419 - val_loss: 0.5186 - val_accuracy: 0.7465
# Epoch 3/20
# 546/546 [==============================] - 139s 254ms/step - loss: 0.4884 - accuracy: 0.7650 - val_loss: 0.4922 - val_accuracy: 0.7582
# Epoch 4/20
# 546/546 [==============================] - 139s 255ms/step - loss: 0.4599 - accuracy: 0.7862 - val_loss: 0.4766 - val_accuracy: 0.7746
# Epoch 5/20
# 546/546 [==============================] - 144s 265ms/step - loss: 0.4391 - accuracy: 0.7989 - val_loss: 0.4633 - val_accuracy: 0.7861
# Epoch 6/20
# 546/546 [==============================] - 144s 263ms/step - loss: 0.4186 - accuracy: 0.8090 - val_loss: 0.4647 - val_accuracy: 0.7810
# Epoch 7/20
# 546/546 [==============================] - 143s 261ms/step - loss: 0.3876 - accuracy: 0.8272 - val_loss: 0.4730 - val_accuracy: 0.7734
# Epoch 8/20
# 546/546 [==============================] - 142s 260ms/step - loss: 0.3636 - accuracy: 0.8401 - val_loss: 0.4468 - val_accuracy: 0.7937
# Epoch 9/20
# 546/546 [==============================] - 139s 255ms/step - loss: 0.3391 - accuracy: 0.8532 - val_loss: 0.4595 - val_accuracy: 0.7906
# Epoch 10/20
# 546/546 [==============================] - 143s 261ms/step - loss: 0.3236 - accuracy: 0.8584 - val_loss: 0.4562 - val_accuracy: 0.7929
# Epoch 11/20
# 546/546 [==============================] - 140s 257ms/step - loss: 0.3008 - accuracy: 0.8716 - val_loss: 0.4757 - val_accuracy: 0.7905
# Epoch 12/20
# 546/546 [==============================] - 141s 258ms/step - loss: 0.2778 - accuracy: 0.8829 - val_loss: 0.4988 - val_accuracy: 0.7867
# Epoch 13/20
# 546/546 [==============================] - 141s 258ms/step - loss: 0.2603 - accuracy: 0.8916 - val_loss: 0.4871 - val_accuracy: 0.7906
# Epoch 14/20
# 546/546 [==============================] - 143s 262ms/step - loss: 0.2415 - accuracy: 0.9024 - val_loss: 0.5149 - val_accuracy: 0.7894
# Epoch 15/20
# 546/546 [==============================] - 143s 261ms/step - loss: 0.2241 - accuracy: 0.9079 - val_loss: 0.5184 - val_accuracy: 0.7928
# Epoch 16/20
# 546/546 [==============================] - 146s 268ms/step - loss: 0.2128 - accuracy: 0.9135 - val_loss: 0.5327 - val_accuracy: 0.7858
# Epoch 17/20
# 546/546 [==============================] - 142s 261ms/step - loss: 0.1952 - accuracy: 0.9242 - val_loss: 0.5615 - val_accuracy: 0.7901
# Epoch 18/20
# 546/546 [==============================] - 145s 266ms/step - loss: 0.1767 - accuracy: 0.9305 - val_loss: 0.5835 - val_accuracy: 0.7834
# Epoch 19/20
# 546/546 [==============================] - 144s 265ms/step - loss: 0.1651 - accuracy: 0.9364 - val_loss: 0.5906 - val_accuracy: 0.7929
# Epoch 20/20
# 546/546 [==============================] - 143s 263ms/step - loss: 0.1462 - accuracy: 0.9461 - val_loss: 0.6270 - val_accuracy: 0.7835
# 3-conv-128-nodes-0-dense-1622052226
# Epoch 1/20
# 121/546 [=====>........................] - ETA: 1:55 - loss: 0.6901 - accuracy: 0.5385
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-b86c53a92dde> in <module>
#      66             y = np.array(y)
#      67
# ---> 68             model.fit(X, y,
#      69                       batch_size=32,
#      70                       epochs=20,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1181                 _r=1):
#    1182               callbacks.on_train_batch_begin(step)
# -> 1183               tmp_logs = self.train_function(iterator)
#    1184               if data_handler.should_sync:
#    1185                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     887
#     888       with OptionalXlaContext(self._jit_compile):
# --> 889         result = self._call(*args, **kwds)
#     890
#     891       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     915       # In this case we have created variables on the first call, so we run the
#     916       # defunned version which is guaranteed to never create variables.
# --> 917       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     918     elif self._stateful_fn is not None:
#     919       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    3021       (graph_function,
#    3022        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 3023     return graph_function._call_flat(
#    3024         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    3025
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1958         and executing_eagerly):
#    1959       # No tape is watching; skip to running the function.
# -> 1960       return self._build_call_outputs(self._inference_function.call(
#    1961           ctx, args, cancellation_manager=cancellation_manager))
#    1962     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     589       with _InterpolateFunctionError(self):
#     590         if cancellation_manager is None:
# --> 591           outputs = execute.execute(
#     592               str(self.signature.name),
#     593               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# identified best config

import time

import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D

from tensorflow.keras.callbacks import TensorBoard

import pickle

import numpy as np

pickle_in = open("X.pickle","rb")
X = pickle.load(pickle_in)

pickle_in = open("y.pickle","rb")
y = pickle.load(pickle_in)

X = X/255.0

dense_layers = [0]

layer_sizes = [64]

conv_layers = [3]

for dense_layer in dense_layers:
    for layer_size in layer_sizes:
        for conv_layer in conv_layers:
            NAME = "{}-conv-{}-nodes-{}-dense-{}".format(conv_layer, layer_size, dense_layer, int(time.time()))
            tensorboard = TensorBoard(log_dir="logs/{}".format(NAME))
            print(NAME)
            
            model = Sequential()

            model.add(Conv2D(layer_size, (3, 3), input_shape=X.shape[1:]))
            model.add(Activation('relu'))
            model.add(MaxPooling2D(pool_size=(2, 2)))
            
            for l in range(conv_layer - 1):
                model.add(Conv2D(layer_size, (3, 3)))
                model.add(Activation('relu'))
                model.add(MaxPooling2D(pool_size=(2, 2)))
                
            model.add(Flatten())  # this converts our 3D feature maps to 1D feature vectors
            
            for l in range(dense_layer):
                model.add(Dense(512))
                model.add(Activation('relu'))
            

            # model.add(Dense(64))
            # model.add(Activation('relu'))

            model.add(Dense(1))
            model.add(Activation('sigmoid'))

            model.compile(loss='binary_crossentropy',
                          optimizer='adam',
                          metrics=['accuracy'])

            X = np.array(X)
            y = np.array(y)

            model.fit(X, y, 
                      batch_size=32, 
                      epochs=10, 
                      validation_split=0.3, 
                      callbacks=[tensorboard])
            
            model.save('best-CNN.model')
# Out:
# 3-conv-64-nodes-0-dense-1622052268
# Epoch 1/10
# 546/546 [==============================] - 73s 132ms/step - loss: 0.6372 - accuracy: 0.6276 - val_loss: 0.5828 - val_accuracy: 0.6888
# Epoch 2/10
# 546/546 [==============================] - 69s 127ms/step - loss: 0.5564 - accuracy: 0.7157 - val_loss: 0.5221 - val_accuracy: 0.7396
# Epoch 3/10
# 546/546 [==============================] - 69s 126ms/step - loss: 0.5042 - accuracy: 0.7552 - val_loss: 0.5301 - val_accuracy: 0.7259
# Epoch 4/10
# 546/546 [==============================] - 62s 114ms/step - loss: 0.4639 - accuracy: 0.7807 - val_loss: 0.4701 - val_accuracy: 0.7765
# Epoch 5/10
# 546/546 [==============================] - 58s 106ms/step - loss: 0.4310 - accuracy: 0.8001 - val_loss: 0.4486 - val_accuracy: 0.7850
# Epoch 6/10
# 546/546 [==============================] - 56s 103ms/step - loss: 0.3981 - accuracy: 0.8185 - val_loss: 0.4433 - val_accuracy: 0.7904
# Epoch 7/10
# 546/546 [==============================] - 57s 104ms/step - loss: 0.3767 - accuracy: 0.8313 - val_loss: 0.4714 - val_accuracy: 0.7781
# Epoch 8/10
# 546/546 [==============================] - 57s 104ms/step - loss: 0.3487 - accuracy: 0.8454 - val_loss: 0.4444 - val_accuracy: 0.7932
# Epoch 9/10
# 546/546 [==============================] - 60s 110ms/step - loss: 0.3248 - accuracy: 0.8564 - val_loss: 0.4483 - val_accuracy: 0.7928
# Epoch 10/10
# 546/546 [==============================] - 60s 111ms/step - loss: 0.2965 - accuracy: 0.8710 - val_loss: 0.4681 - val_accuracy: 0.7976
# INFO:tensorflow:Assets written to: best-CNN.model\assets

# %%
# Using the trained model with best configuration

import cv2
import tensorflow as tf

CATEGORIES = ["Dog", "Cat"]

def prepare(filepath):
    IMG_SIZE = 50
    img_array = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
    return new_array.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

model = tf.keras.models.load_model("best-CNN.model")

# %%
prediction = model.predict([prepare("dog.jpg")])
print(CATEGORIES[int(prediction[0][0])])
# Out:
# Dog

# %%
prediction = model.predict([prepare("cat.jpg")])
print(CATEGORIES[int(prediction[0][0])])
# Out:
# Cat
